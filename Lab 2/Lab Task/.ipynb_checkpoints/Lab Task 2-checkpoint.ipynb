# %% [markdown]
# # Digital Image Processing Lab
# ## Lab 2
# ## Bahria University Islamabad
#
# Name: Saadat Hussain
# Enrollment: 01-134211-078
# Class-Section: BSCS 7-B

# %% [markdown]
# ### Importing Dependencies

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ### Task 1
# Practice loading images using different methods and paths in Python with OpenCV.
# You will use the
# following approaches to load images  :
# 1. Image in the Same Folder
# 2. Image in a Different Folder
# 3. Image Using an Absolute Path
# 4. Image Using a Relative Path

# %% [markdown]
# #### 1. Image in the Same Folder

# %%
img_in_same_folder = cv2.imread("2.png")

# %%
#Displaying the image
cv2.imshow("image", img_in_same_folder)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### 2. Image in the Different Folder

# %%
img_in_different_folder = cv2.imread(r"../images/2.png")

# %%
#Displaying the image
cv2.imshow("image", img_in_different_folder)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### 3. Image Using an Absolute Path

# %%
img_using_absolute_path = cv2.imread(r"C:\Users\user\Jupyter Projects\DIP Lab\Lab 2\images\2.png")

# %%
#Displaying the image
cv2.imshow("image", img_using_absolute_path)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### 4. Image Using a Relative Path

# %%
img_using_relative_path = cv2.imread(r".\images\2.png")

# %%
#Displaying the image
cv2.imshow("image", img_using_relative_path)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Task 2
# Learn how to find and display the dimensions of an image using Python and OpenCV.
# This task will help
# you understand how to retrieve image dimensions and use them in image processing.

# %%
img = cv2.imread("2.png")
height, width, channel = img.shape
print('width:  ', width)
print('height: ', height)
print('channel:', channel)
print("Shape: ", img.shape)
print('\n')
print("Numpy Array:\n", img)
# Out:
# width:   676
# height:  470
# channel: 3
# Shape:  (470, 676, 3)
#
#
# Numpy Array:
#  [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
# ### Task 3
# Learn how to load and display an image using three different libraries: PIL (Pillow), Matplotlib, and
# OpenCV. This task will help you understand how to handle images in various Python libraries.

# %% [markdown]
# ### Loading the image in Pillow

# %%
pillow_img = Image.open('2.png')

# %%
pillow_img.show()

# %% [markdown]
# ### Loading the image in Matplotlib

# %%
matplotlib_image = plt.imread(r'2.png')

# %%
# Display the image
plt.imshow(matplotlib_image)
plt.title('Image using Matplotlib')
plt.show()

# %% [markdown]
# ### Task 4
# Learn how to split an image into its individual color channels (Blue, Green, and Red) using Python and
# OpenC.  This task will help you understand how to access and manipulate different colo  components o
# an image.

# %% [markdown]
# ### Splitting the Image and displaying all three channels

# %%
b, g, r = cv2.split(img)

# Convert BGR to RGB for correct color display in matplotlib
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Original Image

# %%
plt.imshow(rgb_img)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Blue Channel

# %%
plt.imshow(b, cmap='Blues')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Green Channel

# %%
plt.imshow(g, cmap='Greens')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Red Channel

# %%
plt.imshow(r, cmap='Reds')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Task 5
# Write a program that loads iris data set:
#
# Explanation: The iris data set comprises data of 3 different flower species of the Iris plant. The first four columns of the data set represent sepal length, sepal width, petal length and petal width respectively. The last column is a label which tells the type of flower (1,2 or 3). The first 50 rows correspond to type 1, the next 50 rows to type 2 and the last 50 rows to type 3.

# %% [markdown]
# ### Loading and Displaying the Iris Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Task 6
# Learn how to convert a color image to grayscale manually using Python and OpenCV. This task will help
# you understand the underlying process of grayscale conversion.

# %%
original_image = cv2.imread(image_path)

# Convert BGR to RGB for correct color display in matplotlib
original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Extracting color channels and applying grayscale conversion formula

# %%
b, g, r = cv2.split(original_image)

# Applying grayscale conversion formula:
gray_values = 0.299 * r + 0.587 * g + 0.114 * b

# %% [markdown]
# ### Creating and displaying the grayscale image

# %%
grayscale_image = np.stack([gray_values, gray_values, gray_values], axis=-1).astype(np.uint8)

plt.imshow(original_image_rgb)
plt.title('Original Image')
plt.axis('off')
plt.show()


plt.imshow(grayscale_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()
